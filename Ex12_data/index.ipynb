# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
line_up, = ax.plot([1, 2, 3, 4, 4, 5, 6, 2, 3, 2, 5, 9], label='PRODUTO A')
line_down, = ax.plot([3, 2, 1, 4, 6, 8, 8, 9, 0, 8, 7, 6], label='PRODUTO B')
ax.legend(handles=[line_up, line_down])
